# %%
import os

# Cloning TumorSemSeg framework repository from GitHub
# !git clone https://github.com/jriverosesma/tumor-semseg

# Choose the repository folder as current directory
os.chdir("tumor-semseg")
# Out:
# Cloning into 'tumor-semseg'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 96 (delta 9), reused 21 (delta 7), pack-reused 29
# Receiving objects: 100% (96/96), 314.54 KiB | 7.67 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %% [markdown]
# # [Tumor Semantic Segmentation](https://github.com/jriverosesma/tumor-semseg)
#
# [![Unit tests](https://github.com/jriverosesma/python-project/actions/workflows/unit_tests.yaml/badge.svg)](https://github.com/jriverosesma/python-project/actions/workflows/unit_tests.yaml)
# [![License](https://img.shields.io/badge/License-MIT-blue.svg)](LICENSE)
# [![Lightning](https://img.shields.io/badge/Lightning-8A2BE2)](https://github.com/Lightning-AI/pytorch-lightning)
# [![Hydra](https://img.shields.io/badge/Hydra-blue)](https://github.com/facebookresearch/hydra)
# [![Aim](https://img.shields.io/badge/Aim-gray)](https://github.com/aimhubio/aim)
#
# <div align="center">
#     <img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/pl.png" alt="PyTorch Lightning" width="200">
#     <img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/hydra.jpeg" alt="Hydra" width="200">
#     <img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/aimstack.png" alt="AimStack" width="200">
# </div>
#
# ## Table of contents
# 1. [Overview](README.md#1-overview)
# 2. [Installation](README.md#2-installation)
# 3. [Quickstart](README.md#3-quickstart)
# 4. [Features](README.md#4-features)
#
# ## 1. Overview
#
# This is a lightweight and flexible Semantic Segmentation framework for MRI tumor detection on [LGG MRI Segmentation Dataset](https://www.kaggle.com/datasets/mateuszbuda/lgg-mri-segmentation).
#
# We can easily extend the framework to new datasets thanks to Lightning datamodules.
#
# <br>
# <div align="center">
#     <table>
#         <tr>
#             <td><img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/pred_1.jpeg" alt="Pred 1" width="200"/></td>
#             <td><img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/pred_2.jpeg" alt="Pred 2" width="200"/></td>
#             <td rowspan="2"><img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/gt_pred.png" alt="GT - Pred" width="500"></td>
#         </tr>
#         <tr>
#             <td><img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/pred_3.jpeg" alt="Pred 3" width="200"/></td>
#             <td><img src="https://raw.githubusercontent.com/jriverosesma/tumor-semseg/main/assets/pred_4.jpeg" alt="Pred 4" width="200"/></td>
#         </tr>
#     </table>
# </div>
#
# ## 2. Installation
#
# ```bash
# git clone https://github.com/jriverosesma/tumor-semantic-segmentation
# conda create -n tumor-semseg python=3.10 --no-default-packages -y
# conda activate tumor-semseg
# python -m pip install --upgrade pip
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# pip install -e .[all]
# pre-commit install
# ```
#
# ## 3. Quickstart
#
# 1. Follow the [installation instructions](README.md#2-installation).
# 2. Download and extract dataset from [Kaggle](https://www.kaggle.com/datasets/mateuszbuda/lgg-mri-segmentation).
# 3. Specify the `dataset_dirpath` in the [main configuration file](tumor_semseg/configuration/main.yaml).
# 4. Train using `semseg_train` command. Run `aim up` in a different terminal to keep track of the training using Aim logger.
# 5. Replace `checkpoint` in the [main configuration file](tumor_semseg/configuration/main.yaml) by the path of the checkpoint saved after training. The best and last epoch models are saved by default in `.aim/<experiment_name>/<run_id>`.
# 6. Run model evaluation using `semseg_eval`.
# 7. Run inferences using `semseg_infer`.
# 8. Export the model to ONNX using `semseg_export`.
#
# ## 4. Features
#
# - Training powered by [Lightning](https://github.com/Lightning-AI/pytorch-lightning) ⚡
# - Easy configuration management using [Hydra](https://github.com/facebookresearch/hydra) ⚙️
# - Supercharged logging using [Aim](https://github.com/aimhubio/aim) 🗃
# - Ready to use scripts:
#     - Train from scratch or from a checkpoint: `semseg_train`.
#     - Compute metrics for model evaluation: `semseg_eval`.
#     - Run inference on images: `semseg_infer`.
#     - Export model to ONNX: `semseg_export`.
# - Direct integration with [Segmentation Models PyTorch](https://github.com/qubvel/segmentation_models.pytorch) via Hydra config: more than 124 encoders and many model architectures ready to use.
# - Hyper-parameter tuning using Optuna plugin for Hydra.
# - Model compression:
#     - Quantized Aware Training using PyTorch quantization modules.
#     - Pruning Aware Training using Lightning callbacks.

# %%
# Install package
# !pip install .
# Out:
# Processing /kaggle/working/tumor-semseg
# done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Pillow<11.0.0,>=10.1.0 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for Pillow<11.0.0,>=10.1.0 from https://files.pythonhosted.org/packages/cb/c3/98faa3e92cf866b9446c4842f1fe847e672b2f54e000cb984157b8095797/pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting aim<4.0.0,>=3.17.5 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for aim<4.0.0,>=3.17.5 from https://files.pythonhosted.org/packages/ae/0c/9ebb03c3daed91f3696198fa955fe1fba1920de21714aeac09ca588dccc1/aim-3.17.5-cp310-cp310-manylinux_2_24_x86_64.whl.metadata
#   Downloading aim-3.17.5-cp310-cp310-manylinux_2_24_x86_64.whl.metadata (37 kB)
# Requirement already satisfied: albumentations<2.0.0,>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from tumor_semseg==0.1.0) (1.3.1)
# Collecting hydra-core<2.0.0,>=1.3.2 (from tumor_semseg==0.1.0)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.8 MB/s eta 0:00:00
# Collecting hydra-optuna-sweeper<2.0.0,>=1.2.0 (from tumor_semseg==0.1.0)
#   Downloading hydra_optuna_sweeper-1.2.0-py3-none-any.whl (8.5 kB)
# Collecting lightning<3.0.0,>=2.1.3 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for lightning<3.0.0,>=2.1.3 from https://files.pythonhosted.org/packages/8c/a1/b2a6c33675510bc3e1ca6d010b244ac0dd9c81fc1723a37e7491aa586041/lightning-2.1.3-py3-none-any.whl.metadata
#   Downloading lightning-2.1.3-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.9 MB/s eta 0:00:00
# Collecting matplotlib==3.8.2 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for matplotlib==3.8.2 from https://files.pythonhosted.org/packages/19/e5/a4ea514515f270224435c69359abb7a3d152ed31b9ee3ba5e63017461945/matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting netron==7.3.6 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for netron==7.3.6 from https://files.pythonhosted.org/packages/0a/b2/0b6758dfafec0b4b3fb55f3acc131e1ba7e929b832ee05c01a61c93c73fa/netron-7.3.6-py3-none-any.whl.metadata
#   Downloading netron-7.3.6-py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy<2.0.0,>=1.26.2 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for numpy<2.0.0,>=1.26.2 from https://files.pythonhosted.org/packages/a5/37/d1453c9ff4f7630e68ec036c6fb56ba0d7c769daa8a4083cb4ef8ee45995/numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.5 MB/s eta 0:00:00
# Collecting omegaconf<3.0.0,>=2.3.0 (from tumor_semseg==0.1.0)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from tumor_semseg==0.1.0) (1.15.0)
# Collecting onnxruntime-gpu<2.0.0,>=1.16.3 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for onnxruntime-gpu<2.0.0,>=1.16.3 from https://files.pythonhosted.org/packages/ac/c2/7f5cb0f36f7385e041453472404870db1be8ba66dcc70854d5103eef9ff0/onnxruntime_gpu-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading onnxruntime_gpu-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting onnxsim<0.5.0,>=0.4.35 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for onnxsim<0.5.0,>=0.4.35 from https://files.pythonhosted.org/packages/da/0b/ba622076ab256e97e3da0febea33df8c90ee6e4c42f34c0213fbcdf74ccd/onnxsim-0.4.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading onnxsim-0.4.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.8.1.78 in /opt/conda/lib/python3.10/site-packages (from tumor_semseg==0.1.0) (4.9.0.80)
# Collecting pandas<3.0.0,>=2.1.4 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for pandas<3.0.0,>=2.1.4 from https://files.pythonhosted.org/packages/b1/67/aca1f6e215d957d24d0a290321f368503305480268f9617bf625243e9dea/pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting prettytable<4.0.0,>=3.9.0 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for prettytable<4.0.0,>=3.9.0 from https://files.pythonhosted.org/packages/4d/81/316b6a55a0d1f327d04cc7b0ba9d04058cb62de6c3a4d4b0df280cbe3b0b/prettytable-3.9.0-py3-none-any.whl.metadata
#   Downloading prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Collecting scikit-learn<2.0.0,>=1.3.2 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for scikit-learn<2.0.0,>=1.3.2 from https://files.pythonhosted.org/packages/3f/61/047b353f0ad550226ef962da182b4a09b689eb6df6bd84a03e44f9ee95bb/scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting segmentation-models-pytorch<0.4.0,>=0.3.3 (from tumor_semseg==0.1.0)
#   Obtaining dependency information for segmentation-models-pytorch<0.4.0,>=0.3.3 from https://files.pythonhosted.org/packages/cb/70/4aac1b240b399b108ce58029ae54bc14497e1bbc275dfab8fd3c84c1e35d/segmentation_models_pytorch-0.3.3-py3-none-any.whl.metadata
#   Downloading segmentation_models_pytorch-0.3.3-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: tqdm==4.66.1 in /opt/conda/lib/python3.10/site-packages (from tumor_semseg==0.1.0) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib==3.8.2->tumor_semseg==0.1.0) (2.8.2)
# Collecting aim-ui==3.17.5 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading aim-ui-3.17.5.tar.gz (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 45.7 MB/s eta 0:00:00
# done
# Collecting aimrecords==0.0.7 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading aimrecords-0.0.7-py2.py3-none-any.whl (28 kB)
# Collecting aimrocks==0.4.0 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading aimrocks-0.4.0-cp310-cp310-manylinux_2_24_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 69.3 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (4.2.4)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (8.1.7)
# Requirement already satisfied: cryptography>=3.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (40.0.2)
# Requirement already satisfied: filelock<4,>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (3.12.2)
# Requirement already satisfied: psutil>=5.6.7 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (5.9.3)
# Collecting py3nvml>=0.2.5 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading py3nvml-0.2.7-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 7.4 MB/s eta 0:00:00
# Collecting RestrictedPython>=5.1 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Obtaining dependency information for RestrictedPython>=5.1 from https://files.pythonhosted.org/packages/5b/85/f40474f97f71e4b7745641635157870f232ce9b7614814d7ce8b82586cb6/RestrictedPython-7.0-py3-none-any.whl.metadata
#   Downloading RestrictedPython-7.0-py3-none-any.whl.metadata (12 kB)
# Collecting aiofiles>=0.5.0 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Obtaining dependency information for aiofiles>=0.5.0 from https://files.pythonhosted.org/packages/c5/19/5af6804c4cc0fed83f47bff6e413a98a36618e7d40185cd36e69737f3b0e/aiofiles-23.2.1-py3-none-any.whl.metadata
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: alembic<2,>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.13.1)
# Requirement already satisfied: fastapi<1,>=0.69.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (0.101.1)
# Requirement already satisfied: jinja2<4,>=2.10.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (3.1.2)
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2023.3)
# Collecting SQLAlchemy<2,>=1.4.1 (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Obtaining dependency information for SQLAlchemy<2,>=1.4.1 from https://files.pythonhosted.org/packages/31/62/1ba10f442303734a3888e16e0c36724a4f5d323a453dcd5fed696707fc41/SQLAlchemy-1.4.51-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading SQLAlchemy-1.4.51-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: uvicorn<1,>=0.12.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (0.23.2)
# Requirement already satisfied: protobuf<5,>=3.9.2 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (3.20.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2.31.0)
# Collecting segment-analytics-python (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Obtaining dependency information for segment-analytics-python from https://files.pythonhosted.org/packages/2a/48/b00bc8b5d9f2f5bc6ca3a42846e78585e7460cb889af65cc62b33a201008/segment_analytics_python-2.2.3-py2.py3-none-any.whl.metadata
#   Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /opt/conda/lib/python3.10/site-packages (from aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.51.1)
# Collecting base58==2.0.1 (from aimrecords==0.0.7->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading base58-2.0.1-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (1.11.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /opt/conda/lib/python3.10/site-packages (from albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (0.21.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (4.9.0.80)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core<2.0.0,>=1.3.2->tumor_semseg==0.1.0)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.7 MB/s eta 0:00:00
# done
# Collecting optuna<3.0.0,>=2.10.0 (from hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 kB 30.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2025.0,>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (2023.12.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (0.10.0)
# Requirement already satisfied: torch<4.0,>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (2.0.0)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (1.2.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (4.5.0)
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (from lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (2.1.3)
# Collecting coloredlogs (from onnxruntime-gpu<2.0.0,>=1.16.3->tumor_semseg==0.1.0)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu<2.0.0,>=1.16.3->tumor_semseg==0.1.0) (23.5.26)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime-gpu<2.0.0,>=1.16.3->tumor_semseg==0.1.0) (1.12)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from onnxsim<0.5.0,>=0.4.35->tumor_semseg==0.1.0) (13.5.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->tumor_semseg==0.1.0) (2023.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prettytable<4.0.0,>=3.9.0->tumor_semseg==0.1.0) (0.2.6)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.3.2->tumor_semseg==0.1.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.3.2->tumor_semseg==0.1.0) (3.2.0)
# Requirement already satisfied: torchvision>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0) (0.15.1)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.4 MB/s eta 0:00:00
# done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# done
# Collecting timm==0.9.2 (from segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0)
#   Obtaining dependency information for timm==0.9.2 from https://files.pythonhosted.org/packages/29/90/94f5deb8d76e24a89813aef95e8809ca8fd7414490428480eda19b133d4a/timm-0.9.2-py3-none-any.whl.metadata
#   Downloading timm-0.9.2-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 7.5 MB/s eta 0:00:00
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0)
#   Obtaining dependency information for munch from https://files.pythonhosted.org/packages/56/b3/7c69b37f03260a061883bec0e7b05be7117c1b1c85f5212c72c8c2bc3c8c/munch-4.0.0-py2.py3-none-any.whl.metadata
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from timm==0.9.2->segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0) (0.20.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm==0.9.2->segmentation-models-pytorch<0.4.0,>=0.3.3->tumor_semseg==0.1.0) (0.4.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic<2,>=1.5.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.15.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from fastapi<1,>=0.69.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.10.12)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi<1,>=0.69.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (0.27.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (3.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2<4,>=2.10.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2.1.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities<2.0,>=0.8.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (68.1.2)
# Collecting cliff (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Obtaining dependency information for cliff from https://files.pythonhosted.org/packages/31/f8/b9989a872192ded4775349abefd32cad60868852a8f892eff3af30be41f8/cliff-4.5.0-py3-none-any.whl.metadata
#   Downloading cliff-4.5.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting cmaes>=0.8.2 (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Obtaining dependency information for cmaes>=0.8.2 from https://files.pythonhosted.org/packages/f7/46/7d9544d453346f6c0c405916c95fdb653491ea2e9976cabb810ba2fe8cd4/cmaes-0.10.0-py3-none-any.whl.metadata
#   Downloading cmaes-0.10.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0) (6.8.0)
# Collecting xmltodict (from py3nvml>=0.2.5->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.8.2->tumor_semseg==0.1.0) (1.16.0)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (3.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations<2.0.0,>=1.3.1->tumor_semseg==0.1.0) (0.3)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<2,>=1.4.1->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2.0.2)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn<1,>=0.12.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (0.14.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu<2.0.0,>=1.16.3->tumor_semseg==0.1.0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->onnxsim<0.5.0,>=0.4.35->tumor_semseg==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->onnxsim<0.5.0,>=0.4.35->tumor_semseg==0.1.0) (2.16.1)
# Collecting monotonic~=1.5 (from segment-analytics-python->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: backoff~=2.1 in /opt/conda/lib/python3.10/site-packages (from segment-analytics-python->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2.2.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime-gpu<2.0.0,>=1.16.3->tumor_semseg==0.1.0) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<3.0.0,>=2.1.3->tumor_semseg==0.1.0) (1.3.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->onnxsim<0.5.0,>=0.4.35->tumor_semseg==0.1.0) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<1,>=0.69.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (3.7.1)
# Collecting autopage>=0.4.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Obtaining dependency information for autopage>=0.4.0 from https://files.pythonhosted.org/packages/9b/63/f1c3fa431e91a52bad5e3602e9d5df6c94d8d095ac485424efa4eeddb4d2/autopage-0.5.2-py3-none-any.whl.metadata
#   Downloading autopage-0.5.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting cmd2>=1.0.0 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Downloading cmd2-2.4.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.2/147.2 kB 16.3 MB/s eta 0:00:00
# Collecting stevedore>=2.0.1 (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Obtaining dependency information for stevedore>=2.0.1 from https://files.pythonhosted.org/packages/4b/68/e739fd061b0aba464bef8e8be48428b2aabbfb3f2f8f2f8ca257363ee6b2/stevedore-5.1.0-py3-none-any.whl.metadata
#   Downloading stevedore-5.1.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<1,>=0.69.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<1,>=0.69.0->aim<4.0.0,>=3.17.5->tumor_semseg==0.1.0) (1.1.3)
# Collecting pyperclip>=1.6 (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# done
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore>=2.0.1->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper<2.0.0,>=1.2.0->tumor_semseg==0.1.0)
#   Obtaining dependency information for pbr!=2.1.0,>=2.0.0 from https://files.pythonhosted.org/packages/64/dd/171c9fb653591cf265bcc89c436eec75c9bde3dec921cc236fa71e5698df/pbr-6.0.0-py2.py3-none-any.whl.metadata
#   Downloading pbr-6.0.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 74.5 MB/s eta 0:00:00
# Downloading netron-7.3.6-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.2 MB/s eta 0:00:00
# Downloading aim-3.17.5-cp310-cp310-manylinux_2_24_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 89.6 MB/s eta 0:00:00
# Downloading lightning-2.1.3-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 75.1 MB/s eta 0:00:00
# Downloading numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 61.8 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.1/157.1 MB 7.8 MB/s eta 0:00:00
# Downloading onnxsim-0.4.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 78.8 MB/s eta 0:00:00
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 78.2 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 93.6 MB/s eta 0:00:00
# Downloading prettytable-3.9.0-py3-none-any.whl (27 kB)
# Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 76.6 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.3.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 12.0 MB/s eta 0:00:00
# Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.7 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading RestrictedPython-7.0-py3-none-any.whl (26 kB)
# Downloading SQLAlchemy-1.4.51-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.8 MB/s eta 0:00:00
# Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl (24 kB)
# Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Downloading cliff-4.5.0-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 9.8 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Downloading autopage-0.5.2-py3-none-any.whl (30 kB)
# Downloading stevedore-5.1.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.0 MB/s eta 0:00:00
# Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 12.3 MB/s eta 0:00:00
# Building wheels for collected packages: tumor_semseg, aim-ui, antlr4-python3-runtime, efficientnet-pytorch, pretrainedmodels, pyperclip
#   Building wheel for tumor_semseg (pyproject.toml) ... done
#   Created wheel for tumor_semseg: filename=tumor_semseg-0.1.0-py3-none-any.whl size=27848 sha256=cf595ed69f4c7983748a66ba19378ff638ba6f960878993b67550c53c1538d62
#   Stored in directory: /root/.cache/pip/wheels/fc/28/35/baaf5c00ce8f6acc77db2d36a4d04f5f9415094f05dada3f69
# done
#   Created wheel for aim-ui: filename=aim_ui-3.17.5-py3-none-any.whl size=21435643 sha256=924f8d66f14b6be97d59908656fc1250ccf2c6a745488135f6f08b7a4a41bd30
#   Stored in directory: /root/.cache/pip/wheels/e6/2b/ec/d686b36856d96cb0cb97cb2f917a17cafb081207446d1b8446
# done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=22295991d7acd8cbc562d266a96f7e9f1f28820e5899527274ac380c5151e454
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=55d2814998701b190f7a771fbeee1735e8b7f8506201537d344865c1a2cb60b9
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60943 sha256=ba73747a7b8e7a09b328f7002aad637a02306b2cc42a3ed1ca56740bb2de03de
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11125 sha256=59679a8cfb12cdf6ea08789e78f551647dd79ab47fa2e3aac66daafdfd91b29b
#   Stored in directory: /root/.cache/pip/wheels/04/24/fe/140a94a7f1036003ede94579e6b4227fe96c840c6f4dcbe307
# Successfully built tumor_semseg aim-ui antlr4-python3-runtime efficientnet-pytorch pretrainedmodels pyperclip
# Installing collected packages: pyperclip, netron, monotonic, antlr4-python3-runtime, aimrocks, aim-ui, xmltodict, SQLAlchemy, RestrictedPython, prettytable, Pillow, pbr, omegaconf, numpy, munch, humanfriendly, cmd2, base58, autopage, aiofiles, stevedore, segment-analytics-python, py3nvml, pandas, hydra-core, coloredlogs, cmaes, aimrecords, scikit-learn, onnxsim, onnxruntime-gpu, matplotlib, efficientnet-pytorch, cliff, timm, pretrainedmodels, optuna, aim, segmentation-models-pytorch, lightning, hydra-optuna-sweeper, tumor_semseg
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.20
#     Uninstalling SQLAlchemy-2.0.20:
#       Successfully uninstalled SQLAlchemy-2.0.20
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.8.0
#     Uninstalling prettytable-3.8.0:
#       Successfully uninstalled prettytable-3.8.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.4
#     Uninstalling matplotlib-3.7.4:
#       Successfully uninstalled matplotlib-3.7.4
#   Attempting uninstall: timm
#     Found existing installation: timm 0.9.12
#     Uninstalling timm-0.9.12:
#       Successfully uninstalled timm-0.9.12
#   Attempting uninstall: optuna
#     Found existing installation: optuna 3.5.0
#     Uninstalling optuna-3.5.0:
#       Successfully uninstalled optuna-3.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.3 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyter-server~=1.16, but you have jupyter-server 2.12.3 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyterlab~=3.4, but you have jupyterlab 4.0.10 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.1 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.1 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.1 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.1 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.51 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.3 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.26.3 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.4 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.1 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.3 which is incompatible.
# tensorflowjs 4.15.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# woodwork 0.27.0 requires numpy<1.25.0,>=1.22.0, but you have numpy 1.26.3 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.26.3 which is incompatible.
# ydata-profiling 4.5.1 requires pandas!=1.4.0,<2.1,>1.1, but you have pandas 2.1.4 which is incompatible.
# Successfully installed Pillow-10.2.0 RestrictedPython-7.0 SQLAlchemy-1.4.51 aim-3.17.5 aim-ui-3.17.5 aimrecords-0.0.7 aimrocks-0.4.0 aiofiles-23.2.1 antlr4-python3-runtime-4.9.3 autopage-0.5.2 base58-2.0.1 cliff-4.5.0 cmaes-0.10.0 cmd2-2.4.3 coloredlogs-15.0.1 efficientnet-pytorch-0.7.1 humanfriendly-10.0 hydra-core-1.3.2 hydra-optuna-sweeper-1.2.0 lightning-2.1.3 matplotlib-3.8.2 monotonic-1.6 munch-4.0.0 netron-7.3.6 numpy-1.26.3 omegaconf-2.3.0 onnxruntime-gpu-1.16.3 onnxsim-0.4.35 optuna-2.10.1 pandas-2.1.4 pbr-6.0.0 pretrainedmodels-0.7.4 prettytable-3.9.0 py3nvml-0.2.7 pyperclip-1.8.2 scikit-learn-1.4.0 segment-analytics-python-2.2.3 segmentation-models-pytorch-0.3.3 stevedore-5.1.0 timm-0.9.2 tumor_semseg-0.1.0 xmltodict-0.13.0

# %%
# Train model - UNet++ with MobileNetv2 encoder
# Check https://github.com/jriverosesma/tumor-semseg to choose from hundreds of model architectures
# !semseg_train "dataset_dirpath=/kaggle/input/lgg-mri-segmentation/kaggle_3m"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [2024-01-18 23:46:21,983][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmpfnb767ov
# [2024-01-18 23:46:21,983][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmpfnb767ov/_remote_module_non_scriptable.py
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|███████████████████████████████████████| 13.6M/13.6M [00:00<00:00, 117MB/s]
# [2024-01-18 23:46:25,781][pytorch_lightning.utilities.rank_zero][INFO] - Using 16bit Automatic Mixed Precision (AMP)
# [2024-01-18 23:46:25,782][pytorch_lightning.utilities.rank_zero][INFO] - Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# [2024-01-18 23:46:25,867][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True (cuda), used: True
# [2024-01-18 23:46:25,868][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2024-01-18 23:46:25,868][pytorch_lightning.utilities.rank_zero][INFO] - IPU available: False, using: 0 IPUs
# [2024-01-18 23:46:25,868][pytorch_lightning.utilities.rank_zero][INFO] - HPU available: False, using: 0 HPUs
# [2024-01-18 23:46:28,158][aim.sdk.reporter][INFO] - creating RunStatusReporter for 1ae9d9b971f1449d92644e55
# [2024-01-18 23:46:28,159][aim.sdk.reporter][INFO] - starting from: {}
# [2024-01-18 23:46:28,159][aim.sdk.reporter][INFO] - starting writer thread for <aim.sdk.reporter.RunStatusReporter object at 0x7f10ec417be0>
# INFO: Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [2024-01-18 23:46:28,628][lightning.fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [2024-01-18 23:46:34,988][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmpgs0wkorn
# [2024-01-18 23:46:34,988][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmpgs0wkorn/_remote_module_non_scriptable.py
# INFO: Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# [2024-01-18 23:46:38,348][lightning.fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# [2024-01-18 23:46:38,426][torch.distributed.distributed_c10d][INFO] - Added key: store_based_barrier_key:1 to store for rank: 0
# [2024-01-18 23:46:38,426][torch.distributed.distributed_c10d][INFO] - Added key: store_based_barrier_key:1 to store for rank: 1
# [2024-01-18 23:46:38,426][torch.distributed.distributed_c10d][INFO] - Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 2 nodes.
# [2024-01-18 23:46:38,426][torch.distributed.distributed_c10d][INFO] - Rank 1: Completed store-based barrier for key:store_based_barrier_key:1 with 2 nodes.
# [2024-01-18 23:46:38,426][pytorch_lightning.utilities.rank_zero][INFO] - ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# [2024-01-18 23:47:08,933][lightning.pytorch.accelerators.cuda][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO: LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# [2024-01-18 23:47:08,933][lightning.pytorch.accelerators.cuda][INFO] - LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO:
#     | Name                                            | Type                 | Params | In sizes                                                                                                  | Out sizes
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0   | model                                           | UnetPlusPlus         | 6.8 M  | [1, 3, 256, 256]                                                                                          | [1, 1, 256, 256]
# 1   | model.encoder                                   | MobileNetV2Encoder   | 2.2 M  | [1, 3, 256, 256]                                                                                          | [[1, 3, 256, 256], [1, 16, 128, 128], [1, 24, 64, 64], [1, 32, 32, 32], [1, 96, 16, 16], [1, 1280, 8, 8]]
# 2   | model.encoder.features                          | Sequential           | 2.2 M  | ?                                                                                                         | ?
# 3   | model.encoder.features.0                        | Conv2dNormActivation | 928    | [1, 3, 256, 256]                                                                                          | [1, 32, 128, 128]
# 4   | model.encoder.features.0.0                      | Conv2d               | 864    | [1, 3, 256, 256]                                                                                          | [1, 32, 128, 128]
# 5   | model.encoder.features.0.1                      | SyncBatchNorm        | 64     | [1, 32, 128, 128]                                                                                         | [1, 32, 128, 128]
# 6   | model.encoder.features.0.2                      | ReLU6                | 0      | [1, 32, 128, 128]                                                                                         | [1, 32, 128, 128]
# 7   | model.encoder.features.1                        | InvertedResidual     | 896    | [1, 32, 128, 128]                                                                                         | [1, 16, 128, 128]
# 8   | model.encoder.features.1.conv                   | Sequential           | 896    | [1, 32, 128, 128]                                                                                         | [1, 16, 128, 128]
# 9   | model.encoder.features.1.conv.0                 | Conv2dNormActivation | 352    | [1, 32, 128, 128]                                                                                         | [1, 32, 128, 128]
# 10  | model.encoder.features.1.conv.0.0               | Conv2d               | 288    | [1, 32, 128, 128]                                                                                         | [1, 32, 128, 128]
# 11  | model.encoder.features.1.conv.0.1               | SyncBatchNorm        | 64     | [1, 32, 128, 128]                                                                                         | [1, 32, 128, 128]
# 12  | model.encoder.features.1.conv.0.2               | ReLU6                | 0      | [1, 32, 128, 128]                                                                                         | [1, 32, 128, 128]
# 13  | model.encoder.features.1.conv.1                 | Conv2d               | 512    | [1, 32, 128, 128]                                                                                         | [1, 16, 128, 128]
# 14  | model.encoder.features.1.conv.2                 | SyncBatchNorm        | 32     | [1, 16, 128, 128]                                                                                         | [1, 16, 128, 128]
# 15  | model.encoder.features.2                        | InvertedResidual     | 5.1 K  | [1, 16, 128, 128]                                                                                         | [1, 24, 64, 64]
# 16  | model.encoder.features.2.conv                   | Sequential           | 5.1 K  | [1, 16, 128, 128]                                                                                         | [1, 24, 64, 64]
# 17  | model.encoder.features.2.conv.0                 | Conv2dNormActivation | 1.7 K  | [1, 16, 128, 128]                                                                                         | [1, 96, 128, 128]
# 18  | model.encoder.features.2.conv.0.0               | Conv2d               | 1.5 K  | [1, 16, 128, 128]                                                                                         | [1, 96, 128, 128]
# 19  | model.encoder.features.2.conv.0.1               | SyncBatchNorm        | 192    | [1, 96, 128, 128]                                                                                         | [1, 96, 128, 128]
# 20  | model.encoder.features.2.conv.0.2               | ReLU6                | 0      | [1, 96, 128, 128]                                                                                         | [1, 96, 128, 128]
# 21  | model.encoder.features.2.conv.1                 | Conv2dNormActivation | 1.1 K  | [1, 96, 128, 128]                                                                                         | [1, 96, 64, 64]
# 22  | model.encoder.features.2.conv.1.0               | Conv2d               | 864    | [1, 96, 128, 128]                                                                                         | [1, 96, 64, 64]
# 23  | model.encoder.features.2.conv.1.1               | SyncBatchNorm        | 192    | [1, 96, 64, 64]                                                                                           | [1, 96, 64, 64]
# 24  | model.encoder.features.2.conv.1.2               | ReLU6                | 0      | [1, 96, 64, 64]                                                                                           | [1, 96, 64, 64]
# 25  | model.encoder.features.2.conv.2                 | Conv2d               | 2.3 K  | [1, 96, 64, 64]                                                                                           | [1, 24, 64, 64]
# 26  | model.encoder.features.2.conv.3                 | SyncBatchNorm        | 48     | [1, 24, 64, 64]                                                                                           | [1, 24, 64, 64]
# 27  | model.encoder.features.3                        | InvertedResidual     | 8.8 K  | [1, 24, 64, 64]                                                                                           | [1, 24, 64, 64]
# 28  | model.encoder.features.3.conv                   | Sequential           | 8.8 K  | [1, 24, 64, 64]                                                                                           | [1, 24, 64, 64]
# 29  | model.encoder.features.3.conv.0                 | Conv2dNormActivation | 3.7 K  | [1, 24, 64, 64]                                                                                           | [1, 144, 64, 64]
# 30  | model.encoder.features.3.conv.0.0               | Conv2d               | 3.5 K  | [1, 24, 64, 64]                                                                                           | [1, 144, 64, 64]
# 31  | model.encoder.features.3.conv.0.1               | SyncBatchNorm        | 288    | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 32  | model.encoder.features.3.conv.0.2               | ReLU6                | 0      | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 33  | model.encoder.features.3.conv.1                 | Conv2dNormActivation | 1.6 K  | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 34  | model.encoder.features.3.conv.1.0               | Conv2d               | 1.3 K  | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 35  | model.encoder.features.3.conv.1.1               | SyncBatchNorm        | 288    | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 36  | model.encoder.features.3.conv.1.2               | ReLU6                | 0      | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 37  | model.encoder.features.3.conv.2                 | Conv2d               | 3.5 K  | [1, 144, 64, 64]                                                                                          | [1, 24, 64, 64]
# 38  | model.encoder.features.3.conv.3                 | SyncBatchNorm        | 48     | [1, 24, 64, 64]                                                                                           | [1, 24, 64, 64]
# 39  | model.encoder.features.4                        | InvertedResidual     | 10.0 K | [1, 24, 64, 64]                                                                                           | [1, 32, 32, 32]
# 40  | model.encoder.features.4.conv                   | Sequential           | 10.0 K | [1, 24, 64, 64]                                                                                           | [1, 32, 32, 32]
# 41  | model.encoder.features.4.conv.0                 | Conv2dNormActivation | 3.7 K  | [1, 24, 64, 64]                                                                                           | [1, 144, 64, 64]
# 42  | model.encoder.features.4.conv.0.0               | Conv2d               | 3.5 K  | [1, 24, 64, 64]                                                                                           | [1, 144, 64, 64]
# 43  | model.encoder.features.4.conv.0.1               | SyncBatchNorm        | 288    | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 44  | model.encoder.features.4.conv.0.2               | ReLU6                | 0      | [1, 144, 64, 64]                                                                                          | [1, 144, 64, 64]
# 45  | model.encoder.features.4.conv.1                 | Conv2dNormActivation | 1.6 K  | [1, 144, 64, 64]                                                                                          | [1, 144, 32, 32]
# 46  | model.encoder.features.4.conv.1.0               | Conv2d               | 1.3 K  | [1, 144, 64, 64]                                                                                          | [1, 144, 32, 32]
# 47  | model.encoder.features.4.conv.1.1               | SyncBatchNorm        | 288    | [1, 144, 32, 32]                                                                                          | [1, 144, 32, 32]
# 48  | model.encoder.features.4.conv.1.2               | ReLU6                | 0      | [1, 144, 32, 32]                                                                                          | [1, 144, 32, 32]
# 49  | model.encoder.features.4.conv.2                 | Conv2d               | 4.6 K  | [1, 144, 32, 32]                                                                                          | [1, 32, 32, 32]
# 50  | model.encoder.features.4.conv.3                 | SyncBatchNorm        | 64     | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 51  | model.encoder.features.5                        | InvertedResidual     | 14.8 K | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 52  | model.encoder.features.5.conv                   | Sequential           | 14.8 K | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 53  | model.encoder.features.5.conv.0                 | Conv2dNormActivation | 6.5 K  | [1, 32, 32, 32]                                                                                           | [1, 192, 32, 32]
# 54  | model.encoder.features.5.conv.0.0               | Conv2d               | 6.1 K  | [1, 32, 32, 32]                                                                                           | [1, 192, 32, 32]
# 55  | model.encoder.features.5.conv.0.1               | SyncBatchNorm        | 384    | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 56  | model.encoder.features.5.conv.0.2               | ReLU6                | 0      | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 57  | model.encoder.features.5.conv.1                 | Conv2dNormActivation | 2.1 K  | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 58  | model.encoder.features.5.conv.1.0               | Conv2d               | 1.7 K  | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 59  | model.encoder.features.5.conv.1.1               | SyncBatchNorm        | 384    | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 60  | model.encoder.features.5.conv.1.2               | ReLU6                | 0      | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 61  | model.encoder.features.5.conv.2                 | Conv2d               | 6.1 K  | [1, 192, 32, 32]                                                                                          | [1, 32, 32, 32]
# 62  | model.encoder.features.5.conv.3                 | SyncBatchNorm        | 64     | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 63  | model.encoder.features.6                        | InvertedResidual     | 14.8 K | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 64  | model.encoder.features.6.conv                   | Sequential           | 14.8 K | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 65  | model.encoder.features.6.conv.0                 | Conv2dNormActivation | 6.5 K  | [1, 32, 32, 32]                                                                                           | [1, 192, 32, 32]
# 66  | model.encoder.features.6.conv.0.0               | Conv2d               | 6.1 K  | [1, 32, 32, 32]                                                                                           | [1, 192, 32, 32]
# 67  | model.encoder.features.6.conv.0.1               | SyncBatchNorm        | 384    | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 68  | model.encoder.features.6.conv.0.2               | ReLU6                | 0      | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 69  | model.encoder.features.6.conv.1                 | Conv2dNormActivation | 2.1 K  | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 70  | model.encoder.features.6.conv.1.0               | Conv2d               | 1.7 K  | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 71  | model.encoder.features.6.conv.1.1               | SyncBatchNorm        | 384    | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 72  | model.encoder.features.6.conv.1.2               | ReLU6                | 0      | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 73  | model.encoder.features.6.conv.2                 | Conv2d               | 6.1 K  | [1, 192, 32, 32]                                                                                          | [1, 32, 32, 32]
# 74  | model.encoder.features.6.conv.3                 | SyncBatchNorm        | 64     | [1, 32, 32, 32]                                                                                           | [1, 32, 32, 32]
# 75  | model.encoder.features.7                        | InvertedResidual     | 21.1 K | [1, 32, 32, 32]                                                                                           | [1, 64, 16, 16]
# 76  | model.encoder.features.7.conv                   | Sequential           | 21.1 K | [1, 32, 32, 32]                                                                                           | [1, 64, 16, 16]
# 77  | model.encoder.features.7.conv.0                 | Conv2dNormActivation | 6.5 K  | [1, 32, 32, 32]                                                                                           | [1, 192, 32, 32]
# 78  | model.encoder.features.7.conv.0.0               | Conv2d               | 6.1 K  | [1, 32, 32, 32]                                                                                           | [1, 192, 32, 32]
# 79  | model.encoder.features.7.conv.0.1               | SyncBatchNorm        | 384    | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 80  | model.encoder.features.7.conv.0.2               | ReLU6                | 0      | [1, 192, 32, 32]                                                                                          | [1, 192, 32, 32]
# 81  | model.encoder.features.7.conv.1                 | Conv2dNormActivation | 2.1 K  | [1, 192, 32, 32]                                                                                          | [1, 192, 16, 16]
# 82  | model.encoder.features.7.conv.1.0               | Conv2d               | 1.7 K  | [1, 192, 32, 32]                                                                                          | [1, 192, 16, 16]
# 83  | model.encoder.features.7.conv.1.1               | SyncBatchNorm        | 384    | [1, 192, 16, 16]                                                                                          | [1, 192, 16, 16]
# 84  | model.encoder.features.7.conv.1.2               | ReLU6                | 0      | [1, 192, 16, 16]                                                                                          | [1, 192, 16, 16]
# 85  | model.encoder.features.7.conv.2                 | Conv2d               | 12.3 K | [1, 192, 16, 16]                                                                                          | [1, 64, 16, 16]
# 86  | model.encoder.features.7.conv.3                 | SyncBatchNorm        | 128    | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 87  | model.encoder.features.8                        | InvertedResidual     | 54.3 K | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 88  | model.encoder.features.8.conv                   | Sequential           | 54.3 K | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 89  | model.encoder.features.8.conv.0                 | Conv2dNormActivation | 25.3 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 90  | model.encoder.features.8.conv.0.0               | Conv2d               | 24.6 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 91  | model.encoder.features.8.conv.0.1               | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 92  | model.encoder.features.8.conv.0.2               | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 93  | model.encoder.features.8.conv.1                 | Conv2dNormActivation | 4.2 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 94  | model.encoder.features.8.conv.1.0               | Conv2d               | 3.5 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 95  | model.encoder.features.8.conv.1.1               | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 96  | model.encoder.features.8.conv.1.2               | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 97  | model.encoder.features.8.conv.2                 | Conv2d               | 24.6 K | [1, 384, 16, 16]                                                                                          | [1, 64, 16, 16]
# 98  | model.encoder.features.8.conv.3                 | SyncBatchNorm        | 128    | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 99  | model.encoder.features.9                        | InvertedResidual     | 54.3 K | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 100 | model.encoder.features.9.conv                   | Sequential           | 54.3 K | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 101 | model.encoder.features.9.conv.0                 | Conv2dNormActivation | 25.3 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 102 | model.encoder.features.9.conv.0.0               | Conv2d               | 24.6 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 103 | model.encoder.features.9.conv.0.1               | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 104 | model.encoder.features.9.conv.0.2               | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 105 | model.encoder.features.9.conv.1                 | Conv2dNormActivation | 4.2 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 106 | model.encoder.features.9.conv.1.0               | Conv2d               | 3.5 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 107 | model.encoder.features.9.conv.1.1               | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 108 | model.encoder.features.9.conv.1.2               | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 109 | model.encoder.features.9.conv.2                 | Conv2d               | 24.6 K | [1, 384, 16, 16]                                                                                          | [1, 64, 16, 16]
# 110 | model.encoder.features.9.conv.3                 | SyncBatchNorm        | 128    | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 111 | model.encoder.features.10                       | InvertedResidual     | 54.3 K | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 112 | model.encoder.features.10.conv                  | Sequential           | 54.3 K | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 113 | model.encoder.features.10.conv.0                | Conv2dNormActivation | 25.3 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 114 | model.encoder.features.10.conv.0.0              | Conv2d               | 24.6 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 115 | model.encoder.features.10.conv.0.1              | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 116 | model.encoder.features.10.conv.0.2              | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 117 | model.encoder.features.10.conv.1                | Conv2dNormActivation | 4.2 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 118 | model.encoder.features.10.conv.1.0              | Conv2d               | 3.5 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 119 | model.encoder.features.10.conv.1.1              | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 120 | model.encoder.features.10.conv.1.2              | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 121 | model.encoder.features.10.conv.2                | Conv2d               | 24.6 K | [1, 384, 16, 16]                                                                                          | [1, 64, 16, 16]
# 122 | model.encoder.features.10.conv.3                | SyncBatchNorm        | 128    | [1, 64, 16, 16]                                                                                           | [1, 64, 16, 16]
# 123 | model.encoder.features.11                       | InvertedResidual     | 66.6 K | [1, 64, 16, 16]                                                                                           | [1, 96, 16, 16]
# 124 | model.encoder.features.11.conv                  | Sequential           | 66.6 K | [1, 64, 16, 16]                                                                                           | [1, 96, 16, 16]
# 125 | model.encoder.features.11.conv.0                | Conv2dNormActivation | 25.3 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 126 | model.encoder.features.11.conv.0.0              | Conv2d               | 24.6 K | [1, 64, 16, 16]                                                                                           | [1, 384, 16, 16]
# 127 | model.encoder.features.11.conv.0.1              | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 128 | model.encoder.features.11.conv.0.2              | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 129 | model.encoder.features.11.conv.1                | Conv2dNormActivation | 4.2 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 130 | model.encoder.features.11.conv.1.0              | Conv2d               | 3.5 K  | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 131 | model.encoder.features.11.conv.1.1              | SyncBatchNorm        | 768    | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 132 | model.encoder.features.11.conv.1.2              | ReLU6                | 0      | [1, 384, 16, 16]                                                                                          | [1, 384, 16, 16]
# 133 | model.encoder.features.11.conv.2                | Conv2d               | 36.9 K | [1, 384, 16, 16]                                                                                          | [1, 96, 16, 16]
# 134 | model.encoder.features.11.conv.3                | SyncBatchNorm        | 192    | [1, 96, 16, 16]                                                                                           | [1, 96, 16, 16]
# 135 | model.encoder.features.12                       | InvertedResidual     | 118 K  | [1, 96, 16, 16]                                                                                           | [1, 96, 16, 16]
# 136 | model.encoder.features.12.conv                  | Sequential           | 118 K  | [1, 96, 16, 16]                                                                                           | [1, 96, 16, 16]
# 137 | model.encoder.features.12.conv.0                | Conv2dNormActivation | 56.4 K | [1, 96, 16, 16]                                                                                           | [1, 576, 16, 16]
# 138 | model.encoder.features.12.conv.0.0              | Conv2d               | 55.3 K | [1, 96, 16, 16]                                                                                           | [1, 576, 16, 16]
# 139 | model.encoder.features.12.conv.0.1              | SyncBatchNorm        | 1.2 K  | [1, 576, 16, 16]                                                                                          | [1, 576, 16, 16]
# 140 | model.encoder.features.12.conv.0.2              | ReLU6                | 0      | [1, 576, 16, 16]                                                                                          | [1, 576, 16, 16]
# 141 | model.encoder.features.12.conv.1                | Conv2dNormActivation | 6.3 K  | [1, 576, 16, 16]                                                                                          | [1, 576, 16, 16]
# 142 | model.encoder.features.12.conv.1.0              | Conv2d               | 5.2 K  | [1, 576, 16, 16]                                                                                          | [1, 576, 16, 16]
# ...
# [2024-01-19 00:17:40,003][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 795590/6788113 (11.72%) -> 819085/6788113 (12.07%)
# Epoch 29: 100%|█| 50/50 [00:51<00:00,  0.98it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:03<00:46,  0.26it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:03<00:21,  0.51it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:04<00:13,  0.75it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:04<00:09,  0.97it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:06,  1.19it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.84it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.98it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.10it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.22it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:07<00:02,  1.34it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.03it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:10<00:00,  1.12it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:10<00:00,  1.20it/s]
# Epoch 29: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 819085/6788113 (12.07%) -> 842580/6788113 (12.41%)
# [2024-01-19 00:18:42,877][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 819085/6788113 (12.07%) -> 842580/6788113 (12.41%)
# Epoch 30: 100%|█| 50/50 [00:51<00:00,  0.97it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:03<00:46,  0.26it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:03<00:21,  0.51it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:04<00:13,  0.74it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:04<00:09,  0.97it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:06,  1.18it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.84it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.98it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.10it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.22it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:07<00:02,  1.34it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.03it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:10<00:00,  1.11it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:10<00:00,  1.20it/s]
# Epoch 30: 100%|█| 50/50 [01:03<00:00,  0.79it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 842580/6788113 (12.41%) -> 866075/6788113 (12.76%)
# [2024-01-19 00:19:46,095][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 842580/6788113 (12.41%) -> 866075/6788113 (12.76%)
# Epoch 30: 100%|█| 50/50 [01:03<00:00,  0.79it/s, v_num=4e55, val_total_loss=0.00INFO: [rank: 0] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# INFO: [rank: 1] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# [2024-01-19 00:19:46,108][lightning.pytorch.callbacks.early_stopping][INFO] - [rank: 0] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# [2024-01-19 00:19:46,108][lightning.pytorch.callbacks.early_stopping][INFO] - [rank: 1] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# Epoch 31: 100%|█| 50/50 [00:51<00:00,  0.97it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:04<00:49,  0.24it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:04<00:22,  0.48it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:04<00:14,  0.70it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:04<00:09,  0.92it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:07,  1.13it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.78it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.91it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.02it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.13it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:08<00:02,  1.25it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.00it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:11<00:00,  1.09it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:11<00:00,  1.17it/s]
# Epoch 31: 100%|█| 50/50 [01:03<00:00,  0.79it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 866075/6788113 (12.76%) -> 889250/6788113 (13.10%)
# [2024-01-19 00:20:49,312][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 866075/6788113 (12.76%) -> 889250/6788113 (13.10%)
# Epoch 31: 100%|█| 50/50 [01:03<00:00,  0.79it/s, v_num=4e55, val_total_loss=0.00INFO: [rank: 0] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# INFO: [rank: 1] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# [2024-01-19 00:20:49,324][lightning.pytorch.callbacks.early_stopping][INFO] - [rank: 0] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# [2024-01-19 00:20:49,324][lightning.pytorch.callbacks.early_stopping][INFO] - [rank: 1] Metric val_total_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.005
# Epoch 32: 100%|█| 50/50 [00:50<00:00,  0.99it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:03<00:46,  0.26it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:03<00:21,  0.51it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:04<00:13,  0.74it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:04<00:09,  0.96it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:06,  1.18it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.80it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.92it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.04it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.15it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:07<00:02,  1.27it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.00it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:11<00:00,  1.09it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:11<00:00,  1.17it/s]
# Epoch 32: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 889250/6788113 (13.10%) -> 912425/6788113 (13.44%)
# [2024-01-19 00:21:51,567][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 889250/6788113 (13.10%) -> 912425/6788113 (13.44%)
# Epoch 33: 100%|█| 50/50 [00:50<00:00,  0.99it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:03<00:43,  0.28it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:03<00:20,  0.55it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:03<00:12,  0.80it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:03<00:08,  1.04it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:03<00:06,  1.27it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.81it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.94it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.06it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.18it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:07<00:02,  1.29it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.04it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:10<00:00,  1.13it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:10<00:00,  1.21it/s]
# Epoch 33: 100%|█| 50/50 [01:01<00:00,  0.81it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 912425/6788113 (13.44%) -> 935600/6788113 (13.78%)
# [2024-01-19 00:22:53,499][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 912425/6788113 (13.44%) -> 935600/6788113 (13.78%)
# Epoch 34: 100%|█| 50/50 [00:51<00:00,  0.98it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:04<00:51,  0.23it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:04<00:23,  0.46it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:04<00:14,  0.68it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:04<00:10,  0.88it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:07,  1.08it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.78it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.91it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.02it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.14it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:08<00:02,  1.25it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.01it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:10<00:00,  1.10it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:11<00:00,  1.18it/s]
# Epoch 34: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 935600/6788113 (13.78%) -> 958775/6788113 (14.12%)
# [2024-01-19 00:23:56,465][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 935600/6788113 (13.78%) -> 958775/6788113 (14.12%)
# Epoch 35: 100%|█| 50/50 [00:50<00:00,  0.99it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:03<00:44,  0.27it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:03<00:20,  0.53it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:03<00:12,  0.77it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:03<00:08,  1.01it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:06,  1.23it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.84it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.97it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.09it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.22it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:07<00:02,  1.34it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.01it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:10<00:00,  1.10it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:10<00:00,  1.18it/s]
# Epoch 35: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 958775/6788113 (14.12%) -> 981950/6788113 (14.47%)
# [2024-01-19 00:24:59,029][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 958775/6788113 (14.12%) -> 981950/6788113 (14.47%)
# Epoch 36: 100%|█| 50/50 [00:50<00:00,  0.99it/s, v_num=4e55, val_total_loss=0.00
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|█▍                 | 1/13 [00:03<00:47,  0.25it/s]
# Validation DataLoader 0:  15%|██▉                | 2/13 [00:03<00:21,  0.50it/s]
# Validation DataLoader 0:  23%|████▍              | 3/13 [00:04<00:13,  0.73it/s]
# Validation DataLoader 0:  31%|█████▊             | 4/13 [00:04<00:09,  0.95it/s]
# Validation DataLoader 0:  38%|███████▎           | 5/13 [00:04<00:06,  1.17it/s]
# Validation DataLoader 0:  46%|████████▊          | 6/13 [00:07<00:08,  0.82it/s]
# Validation DataLoader 0:  54%|██████████▏        | 7/13 [00:07<00:06,  0.95it/s]
# Validation DataLoader 0:  62%|███████████▋       | 8/13 [00:07<00:04,  1.07it/s]
# Validation DataLoader 0:  69%|█████████████▏     | 9/13 [00:07<00:03,  1.18it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 10/13 [00:07<00:02,  1.30it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 11/13 [00:10<00:01,  1.00it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 12/13 [00:11<00:00,  1.09it/s]
# Validation DataLoader 0: 100%|██████████████████| 13/13 [00:11<00:00,  1.17it/s]
# Epoch 36: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00INFO: Applied `ln_structured`. Pruned: 981950/6788113 (14.47%) -> 1005125/6788113 (14.81%)
# [2024-01-19 00:26:01,583][lightning.pytorch.callbacks.pruning][INFO] - Applied `ln_structured`. Pruned: 981950/6788113 (14.47%) -> 1005125/6788113 (14.81%)
# Epoch 36: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00INFO: [rank: 0] Monitored metric val_total_loss did not improve in the last 5 records. Best score: 0.005. Signaling Trainer to stop.
# INFO: [rank: 1] Monitored metric val_total_loss did not improve in the last 5 records. Best score: 0.005. Signaling Trainer to stop.
# [2024-01-19 00:26:01,595][lightning.pytorch.callbacks.early_stopping][INFO] - [rank: 0] Monitored metric val_total_loss did not improve in the last 5 records. Best score: 0.005. Signaling Trainer to stop.
# [2024-01-19 00:26:01,595][lightning.pytorch.callbacks.early_stopping][INFO] - [rank: 1] Monitored metric val_total_loss did not improve in the last 5 records. Best score: 0.005. Signaling Trainer to stop.
# Epoch 36: 100%|█| 50/50 [01:02<00:00,  0.80it/s, v_num=4e55, val_total_loss=0.00

# %%
# Evaluate trained model
import glob

os.environ["CHECKPOINT"] = glob.glob(".aim/tumorsemseg/**/*/*epoch*")[0]
# !semseg_eval "checkpoint='$CHECKPOINT'" "dataset_dirpath=/kaggle/input/lgg-mri-segmentation/kaggle_3m"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [2024-01-19 00:26:12,676][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmppuia08x3
# [2024-01-19 00:26:12,676][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmppuia08x3/_remote_module_non_scriptable.py
# [2024-01-19 00:26:20,952][pytorch_lightning.utilities.rank_zero][INFO] - Using 16bit Automatic Mixed Precision (AMP)
# [2024-01-19 00:26:20,954][pytorch_lightning.utilities.rank_zero][INFO] - Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# [2024-01-19 00:26:21,035][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True (cuda), used: True
# [2024-01-19 00:26:21,035][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2024-01-19 00:26:21,035][pytorch_lightning.utilities.rank_zero][INFO] - IPU available: False, using: 0 IPUs
# [2024-01-19 00:26:21,035][pytorch_lightning.utilities.rank_zero][INFO] - HPU available: False, using: 0 HPUs
# [2024-01-19 00:26:21,092][aim.sdk.reporter][INFO] - creating RunStatusReporter for 1b37e2c94a5d4b3399b993ee
# [2024-01-19 00:26:21,093][aim.sdk.reporter][INFO] - starting from: {}
# [2024-01-19 00:26:21,094][aim.sdk.reporter][INFO] - starting writer thread for <aim.sdk.reporter.RunStatusReporter object at 0x7f44b8234f10>
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# INFO: Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [2024-01-19 00:26:21,757][lightning.fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [2024-01-19 00:26:28,728][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmpd2_acgf5
# [2024-01-19 00:26:28,728][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmpd2_acgf5/_remote_module_non_scriptable.py
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# INFO: Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# [2024-01-19 00:26:37,279][lightning.fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# [2024-01-19 00:26:37,280][torch.distributed.distributed_c10d][INFO] - Added key: store_based_barrier_key:1 to store for rank: 1
# [2024-01-19 00:26:37,281][torch.distributed.distributed_c10d][INFO] - Added key: store_based_barrier_key:1 to store for rank: 0
# [2024-01-19 00:26:37,281][torch.distributed.distributed_c10d][INFO] - Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 2 nodes.
# [2024-01-19 00:26:37,282][pytorch_lightning.utilities.rank_zero][INFO] - ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# [2024-01-19 00:26:37,291][torch.distributed.distributed_c10d][INFO] - Rank 1: Completed store-based barrier for key:store_based_barrier_key:1 with 2 nodes.
# INFO: LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# [2024-01-19 00:26:37,932][lightning.pytorch.accelerators.cuda][INFO] - LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# [2024-01-19 00:26:37,932][lightning.pytorch.accelerators.cuda][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Predicting DataLoader 0: 100%|██████████████████| 50/50 [00:09<00:00,  5.44it/s]
# [2024-01-19 00:26:49,404][aim.sdk.reporter][INFO] - creating RunStatusReporter for 1b37e2c94a5d4b3399b993ee
# [2024-01-19 00:26:49,405][aim.sdk.reporter][INFO] - starting from: {}
# [2024-01-19 00:26:49,405][aim.sdk.reporter][INFO] - starting writer thread for <aim.sdk.reporter.RunStatusReporter object at 0x7f44b8041300>
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO: LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# [2024-01-19 00:26:49,491][lightning.pytorch.accelerators.cuda][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# [2024-01-19 00:26:49,491][lightning.pytorch.accelerators.cuda][INFO] - LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Predicting DataLoader 0: 100%|██████████████████| 13/13 [00:02<00:00,  5.86it/s]
# +--------------------------------------------+
# |         Evaluation Summary (train)         |
# +---------------------+----------------------+
# |  Number of samples  |         1571         |
# | Mean per class Dice | [0.9254196882247925] |
# |  Mean per class IoU | [0.8976264595985413] |
# |      Mean Dice      |  0.9254196882247925  |
# |       Mean IoU      |  0.8976264595985413  |
# +---------------------+----------------------+
# +--------------------------------------------+
# |          Evaluation Summary (val)          |
# +---------------------+----------------------+
# |  Number of samples  |         393          |
# | Mean per class Dice | [0.9071021676063538] |
# |  Mean per class IoU | [0.8795520663261414] |
# |      Mean Dice      |  0.9071021676063538  |
# |       Mean IoU      |  0.8795520663261414  |
# +---------------------+----------------------+
# +--------------------------------------------+
# |        Evaluation Summary (global)         |
# +---------------------+----------------------+
# |  Number of samples  |         1964         |
# | Mean per class Dice | [0.9217543005943298] |
# |  Mean per class IoU | [0.8940097093582153] |
# |      Mean Dice      |  0.9217543005943298  |
# |       Mean IoU      |  0.8940097093582153  |
# +---------------------+----------------------+
# +--------------------------------------------+
# |         Evaluation Summary (train)         |
# +---------------------+----------------------+
# |  Number of samples  |         1572         |
# | Mean per class Dice | [0.9275000095367432] |
# |  Mean per class IoU | [0.8998499512672424] |
# |      Mean Dice      |  0.9275000095367432  |
# |       Mean IoU      |  0.8998499512672424  |
# +---------------------+----------------------+
# +--------------------------------------------+
# |          Evaluation Summary (val)          |
# +---------------------+----------------------+
# |  Number of samples  |         393          |
# | Mean per class Dice | [0.9128842949867249] |
# |  Mean per class IoU | [0.8832899332046509] |
# |      Mean Dice      |  0.9128842949867249  |
# |       Mean IoU      |  0.8832899332046509  |
# +---------------------+----------------------+
# +--------------------------------------------+
# |        Evaluation Summary (global)         |
# +---------------------+----------------------+
# |  Number of samples  |         1965         |
# | Mean per class Dice | [0.9245769381523132] |
# |  Mean per class IoU | [0.8965378999710083] |
# |      Mean Dice      |  0.9245769381523132  |
# |       Mean IoU      |  0.8965378999710083  |
# +---------------------+----------------------+

# %%
# Run inference on images
# !semseg_infer "checkpoint='$CHECKPOINT'" "dataset_dirpath=/kaggle/input/lgg-mri-segmentation/kaggle_3m"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [2024-01-19 00:27:04,040][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmp49_z3sbt
# [2024-01-19 00:27:04,040][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmp49_z3sbt/_remote_module_non_scriptable.py
# 100%|█████████████████████████████████████████| 123/123 [12:57<00:00,  6.32s/it]

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import random
import cv2

# Retrieve inferece image filepaths
pred_img_paths = glob.glob("/kaggle/working/tumor-semseg/preds/*.jpeg")

# Read images
imgs = [cv2.cvtColor(cv2.imread(p), cv2.COLOR_BGR2RGB) for p in pred_img_paths]

# Function to create image grid
def create_grid(images):
    plt.figure(figsize=(10, 6))
    gs = gridspec.GridSpec(2, 3)
    for i in range(6):
        ax = plt.subplot(gs[i])
        ax.imshow(images[i])
        ax.axis('off')

    plt.tight_layout()
    plt.show()
    plt.close()

# %%
# Display inference example
create_grid(random.choices(imgs, k=6))

# %%
# Export model to ONNX
# !semseg_export "checkpoint='$CHECKPOINT'"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [2024-01-19 00:40:18,661][torch.distributed.nn.jit.instantiator][INFO] - Created a temporary directory at /tmp/tmp2xpy7j6b
# [2024-01-19 00:40:18,661][torch.distributed.nn.jit.instantiator][INFO] - Writing /tmp/tmp2xpy7j6b/_remote_module_non_scriptable.py
# /opt/conda/lib/python3.10/site-packages/segmentation_models_pytorch/base/model.py:16: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if h % output_stride != 0 or w % output_stride != 0:
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Checking 0/10...
# Checking 1/10...
# Checking 2/10...
# Checking 3/10...
# Checking 4/10...
# Checking 5/10...
# Checking 6/10...
# Checking 7/10...
# Checking 8/10...
# Checking 9/10...
